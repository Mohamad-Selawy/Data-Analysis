# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohamad-Selawy/Data-Analysis/blob/main/Data%20Analysis/Level%201/5_Aggregation_%26_Pivoting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GroupBy and Pivot Tables: Advanced Data Summarization
#
# _Use `groupby()` to split-apply-combine data, and `pivot_table()` and `pivot()` to reshape and summarize_
#
# ## What You'll Learn
# - How to use `groupby()` to compute grouped statistics.
# - How to create pivot tables for aggregated summaries using `pd.pivot_table()`.
# - Key differences and use-cases for `groupby()` vs. `pivot_table()`

# %% [markdown]
# ## 0. Setup: Import Libraries and Load Data

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 0.1 Load Dataset

# %% [markdown]
# We will load the `Data_Selection_&_Filtering.csv` dataset into a pandas DataFrame (`df`). This dataset will be used throughout the notebook to demonstrate `groupby()`, `pivot_table()`, and `df.pivot()` functionalities.

# %%
# Load the dataset
df = pd.read_csv('/content/Data_Selection_&_Filtering.csv')

print("First 5 rows of the dataset:")
display(df.head())

print("\nDataset Information:")
df.info()

print("\nColumns in the dataset:")
print(df.columns.tolist())
# Out:
# First 5 rows of the dataset:
#    EmployeeID           Name Department  Age  Gender  Salary  Experience  \
# 0         101    Alice Smith         IT   26  Female   60278          22
# 1         102    Bob Johnson         HR   32    Male   87849           6
# 2         103  Charlie Brown    Finance   57    Male   83428           5
# 3         104   Diana Prince  Marketing   47  Female   65282          26
# 4         105      Eve Adams         IT   42  Female   62734          17
#
#        City  PerformanceScore
# 0  New York                71
# 1    London                94
# 2     Paris                78
# 3     Tokyo                86
# 4    Berlin                78
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   EmployeeID        20 non-null     int64
#  1   Name              20 non-null     object
# ...

# %% [markdown]
# ## 1. `groupby()` - Split, Apply, Combine
#
# The `groupby()` method is fundamental for aggregating data. It involves three steps: **Split** (dividing data into groups based on some criteria), **Apply** (applying a function to each group independently), and **Combine** (combining the results into a data structure). This section demonstrates grouping by single and multiple columns, and applying multiple aggregation functions.
#
# ---
# ### Grouping by a Single Column
#
# **Business Question:** *What is the average `Salary` for each `Department`?*
#
# We will group the data by `Department` and calculate the mean of the `Salary` column.

# %%
# Group by 'Department' and calculate the mean of 'Salary'
avg_salary_by_department = df.groupby('Department')['Salary'].mean()
display(avg_salary_by_department)
# Out:
# Department
# Finance      75407.00
# HR           77171.75
# IT           76251.00
# Marketing    88246.25
# Sales        83826.25
# Name: Salary, dtype: float64

# %% [markdown]
# ---
# ### Grouping by Multiple Columns
#
# **Business Question:** *What is the total `PerformanceScore` for each `Department` within each `City`?*
#
# Here, we group by both `Department` and `City` to get a more granular breakdown.

# %%
# Group by 'Department' and 'City', then sum 'PerformanceScore'
total_performance_by_dept_city = df.groupby(['Department', 'City'])['PerformanceScore'].sum()
display(total_performance_by_dept_city)
# Out:
# Department  City
# Finance     Berlin       90
#             Paris        78
#             Tokyo        88
# HR          London      179
#             Paris       165
# IT          Berlin       78
#             London       75
#             New York    146
#             Paris        93
# Marketing   Berlin       75
#             Tokyo       269
# Sales       Berlin       74
#             London       75
#             New York    154
# Name: PerformanceScore, dtype: int64

# %% [markdown]
# ---
# ### Applying Multiple Aggregation Functions
#
# **Business Question:** *For each `Department`, what are the average, maximum, and minimum `Salary`, and the median `Experience`?*
#
# The `.agg()` method allows us to apply different aggregation functions to one or more columns simultaneously.
#
# ---
#
# ### Practice Exercise: GroupBy
#
# **Challenge:** *Calculate the minimum, maximum, and average `Age` for each `Gender` and `Department` combination.*
#
# **Hint:** Use `df.groupby()` with multiple columns and `.agg()` with a dictionary of functions.
#
# ```python
# # Your code here
# # df.groupby(['Gender', 'Department']).agg(MinAge=('Age', 'min'), MaxAge=('Age', 'max'), AvgAge=('Age', 'mean'))
# ```

# %%
# Using dictionary syntax for .agg()
dept_stats = df.groupby('Department').agg({
    'Salary': ['mean', 'max', 'min'],
    'Experience': 'median',
    'PerformanceScore': 'mean'
})
display(dept_stats)
# Out:
#               Salary                Experience PerformanceScore
#                 mean     max    min     median             mean
# Department
# Finance     75407.00   88227  54566        8.0        85.333333
# HR          77171.75  111177  52436       25.0        86.000000
# IT          76251.00  101577  60278       17.0        78.400000
# Marketing   88246.25  106375  65282       22.5        86.000000
# Sales       83826.25  115720  53088       12.0        75.750000

# %%
# Using named aggregation for .agg() for clearer output column names
dept_detailed_stats = df.groupby('Department').agg(
    AvgSalary=('Salary', 'mean'),
    MaxSalary=('Salary', 'max'),
    MedianExperience=('Experience', 'median'),
    AvgPerformance=('PerformanceScore', 'mean')
).reset_index() # .reset_index() turns the grouped column back into a regular column
display(dept_detailed_stats)
# Out:
#   Department  AvgSalary  MaxSalary  MedianExperience  AvgPerformance
# 0    Finance   75407.00      88227               8.0       85.333333
# 1         HR   77171.75     111177              25.0       86.000000
# 2         IT   76251.00     101577              17.0       78.400000
# 3  Marketing   88246.25     106375              22.5       86.000000
# 4      Sales   83826.25     115720              12.0       75.750000

# %% [markdown]
# ## 2. `pivot_table()` - Flexible Table Generator
#
# The `pivot_table()` function is used to create spreadsheet-style pivot tables as a DataFrame. It summarizes data by specifying `index`, `columns`, `values`, and `aggfunc`. It's very powerful because it can handle duplicate combinations of `index` and `columns` by automatically aggregating the `values`.
#
# ---
# ### Basic Pivot Table
#
# **Business Question:** *How does the average `Salary` compare across different `Department` by `City`?*
#
# We will create a pivot table with `Department` as rows (index), `City` as columns, and the average `Salary` as the values.

# %%
# Pivot table showing average Salary by Department and City
avg_salary_pivot = pd.pivot_table(df,
                                       values='Salary',
                                       index='Department',
                                       columns='City',
                                       aggfunc='mean')
display(avg_salary_pivot)
# Out:
# City          Berlin   London  New York    Paris         Tokyo
# Department
# Finance      54566.0      NaN       NaN  83428.0  88227.000000
# HR               NaN  70142.5       NaN  84201.0           NaN
# IT           62734.0  65307.0   80927.5  91359.0           NaN
# Marketing    76572.0      NaN       NaN      NaN  92137.666667
# Sales       103158.0  63339.0   84404.0      NaN           NaN

# %%
# Pivot table with fill_value and margins
# fill_value replaces NaN (missing combinations) with 0
# margins=True adds row and column totals ('All')
pivot_with_totals = pd.pivot_table(df,
                                         values='Salary',
                                         index='Department',
                                         columns='City',
                                         aggfunc='mean',
                                         fill_value=0, # Replace NaN with 0 for cleaner display
                                         margins=True) # Adds row and column totals
display(pivot_with_totals)
# Out:
# City          Berlin    London  New York     Paris         Tokyo       All
# Department
# Finance      54566.0      0.00      0.00  83428.00  88227.000000  75407.00
# HR               0.0  70142.50      0.00  84201.00      0.000000  77171.75
# IT           62734.0  65307.00  80927.50  91359.00      0.000000  76251.00
# Marketing    76572.0      0.00      0.00      0.00  92137.666667  88246.25
# Sales       103158.0  63339.00  84404.00      0.00      0.000000  83826.25
# All          74257.5  67232.75  82665.75  85797.25  91160.000000  80222.65

# %% [markdown]
# ---
# ### Pivot Table with Multiple Values and Aggregations
#
# **Business Question:** *For each `Department`, what are the total `Salary`, maximum `PerformanceScore`, and sum of `Experience`?*
#
# We can specify multiple `values` and different `aggfunc` for each value using a dictionary.

# %%
# Pivot table with multiple values and different aggregation functions
multi_agg_pivot = pd.pivot_table(df,
                                       values=['Salary', 'PerformanceScore', 'Experience'],
                                       index='Department',
                                       aggfunc={'Salary': 'sum', 'PerformanceScore': 'max', 'Experience': 'sum'},
                                       fill_value=0)
display(multi_agg_pivot)
# Out:
#             Experience  PerformanceScore  Salary
# Department
# Finance             33                90  226221
# HR                  85                94  308687
# IT                  76                93  381255
# Marketing           84                92  352985
# Sales               53                78  335305

# %% [markdown]
# ## Key Differences
#
# | Feature       | `groupby()`                  | `pivot_table()`                            |
# |:------------- |:---------------------------- |:------------------------------------------ |
# | Use Case      | Grouping + aggregation logic | Tabular summarization                      |
# | Output Format | Series or DataFrame          | Matrix-style DataFrame                     |
# | Flexibility   | High                         | Higher for tables (index/columns/aggfuncs) |
# | Null Handling | Keeps NaNs                   | Can handle NaNs using `fill_value`         |
#
# ---
#
# ### Summary: GroupBy & Pivot Tables
#
# *   `groupby()` is excellent for programmatic analysis and applying various aggregations (including custom functions) on grouped data.
# *   `pivot_table()` is ideal for creating cross-tabulations or spreadsheet-style summaries for reporting and multi-dimensional analysis.
